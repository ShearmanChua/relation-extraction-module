# %%
from transformers import LongformerForMaskedLM, LongformerModel, LongformerTokenizer, LongformerConfig, AdamW, get_linear_schedule_with_warmup
from transformers.models.longformer.modeling_longformer import LongformerLMHead, _compute_global_attention_mask

# %% [markdown]
# # Generate entities_classes.json and relation_classes.json

# %%
import json
  
# Opening JSON file
f = open('../data/docred_joint/types.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
entities = data['entities']
relations = data['relations']

# %%
entities_simplified = []

for entity,entitity_dict in entities.items():
    entities_simplified.append(entity)

# %%
entities_simplified
# Out:
# ['LOC', 'MISC', 'PER', 'NUM', 'TIME', 'ORG']

# %%
relations_simplified = []

for relation,relation_dict in relations.items():
    relation_string = relation_dict['verbose'].title()
    relation_string = relation_string.replace(" ","")
    relations_simplified.append(relation_string)

# %%
relations_simplified
# Out:
# ['CapitalOf',
#  'Conflict',
#  'Genre',
#  'Operator',
#  'LocatedInTheAdministrativeTerritorialEntity',
#  'HasPart',
#  'LanguagesSpoken,WrittenOrSigned',
#  'LocatedInOrNextToBodyOfWater',
#  'BasinCountry',
#  'OriginalNetwork',
#  'OwnedBy',
#  'Publisher',
#  'Composer',
#  'NarrativeLocation',
#  'Subsidiary',
#  'InfluencedBy',
#  'LocationOfFormation',
#  'SisterCity',
#  'Dissolved,AbolishedOrDemolished',
#  'LegislativeBody',
#  'FoundedBy',
#  'League',
#  'Country',
#  'PlaceOfBirth',
#  'Sibling',
#  'HeadOfGovernment',
#  'Location',
#  'AppliesToJurisdiction',
#  'StartTime',
#  'EndTime',
#  'PointInTime',
#  'MemberOf',
#  'LyricsBy',
#  'Characters',
#  'RecordLabel',
#  'Employer',
#  'MemberOfPoliticalParty',
#  'Mother',
#  'CountryOfCitizenship',
#  'Spouse',
#  'PlaceOfDeath',
#  'Father',
#  'SeparatedFrom',
#  'NotableWork',
#  'SubclassOf',
#  'TerritoryClaimedBy',
#  'PublicationDate',
#  'DateOfDeath',
#  'Inception',
#  'Developer',
#  'Series',
#  'ProductionCompany',
#  'Creator',
#  'ParentTaxon',
#  'EthnicGroup',
#  'Performer',
#  'Manufacturer',
#  'PositionHeld',
#  'Continent',
#  'InstanceOf',
#  'Capital',
#  'OfficialLanguage',
#  'HeadOfState',
#  'Platform',
#  'MouthOfTheWatercourse',
#  'PartOf',
#  'OriginalLanguageOfWork',
#  'DateOfBirth',
#  'Participant',
#  'ParticipantOf',
#  'Chairperson',
#  'MilitaryBranch',
#  'Producer',
#  'CastMember',
#  'AwardReceived',
#  'Child',
#  'PresentInWork',
#  'FollowedBy',
#  'Follows',
#  'ContainsAdministrativeTerritorialEntity',
#  'Residence',
#  'LocatedOnTerrainFeature',
#  'HeadquartersLocation',
#  'CountryOfOrigin',
#  'Screenwriter',
#  'ParentOrganization',
#  'MemberOfSportsTeam',
#  'Director',
#  'Author',
#  'ReplacedBy',
#  'Replaces',
#  'WorkLocation',
#  'Religion',
#  'EducatedAt',
#  'UnemploymentRate',
#  'ProductOrMaterialProduced']

# %%
entity_dict = {"docred":entities_simplified}
relation_dict = {"docred":relations_simplified}
    
with open("../data/docred_joint/entity_classes.json", "w") as outfile:
    json.dump(entity_dict, outfile)
    
with open("../data/docred_joint/relation_classes.json", "w") as outfile:
    json.dump(relation_dict, outfile)

# %% [markdown]
# # Create train json

# %%
f = open('../data/docred_joint/test_joint.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
data[0]
# Out:
# {'vertexSet': [[{'name': 'Jeff Prosserman',
#     'pos': [0, 2],
#     'sent_id': 0,
#     'type': 'PER'},
#    {'type': 'PER', 'pos': [7, 8], 'name': 'Prosserman', 'sent_id': 7},
#    {'type': 'PER', 'pos': [6, 7], 'name': 'Prosserman', 'sent_id': 1},
#    {'type': 'PER', 'pos': [7, 8], 'name': 'Prosserman', 'sent_id': 6},
#    {'type': 'PER', 'pos': [13, 14], 'name': 'Prosserman', 'sent_id': 8},
#    {'type': 'PER', 'pos': [0, 1], 'name': 'Prosserman', 'sent_id': 2},
#    {'type': 'PER', 'pos': [0, 1], 'name': 'Prosserman', 'sent_id': 5}],
#   [{'type': 'TIME', 'pos': [4, 8], 'name': 'November 2, 1983', 'sent_id': 0}],
#   [{'name': 'Canadian', 'pos': [11, 12], 'sent_id': 0, 'type': 'LOC'}],
#   [{'type': 'ORG', 'pos': [3, 5], 'name': 'LIVESTAGE °', 'sent_id': 1},
#    {'name': 'LIVESTAGE °', 'pos': [10, 12], 'sent_id': 8, 'type': 'ORG'}],
#   [{'type': 'ORG', 'pos': [11, 13], 'name': 'Gusto Goods', 'sent_id': 1}],
#   [{'name': 'New York', 'pos': [19, 21], 'sent_id': 1, 'type': 'LOC'}],
#   [{'name': 'Toronto', 'pos': [22, 23], 'sent_id': 1, 'type': 'LOC'},
#    {'name': 'Toronto', 'pos': [4, 5], 'sent_id': 2, 'type': 'LOC'}],
#   [{'name': 'Ontario', 'pos': [6, 7], 'sent_id': 2, 'type': 'LOC'}],
#   [{'name': 'Canada', 'pos': [8, 9], 'sent_id': 2, 'type': 'LOC'},
#    {'name': 'Canada', 'pos': [23, 24], 'sent_id': 4, 'type': 'LOC'}],
#   [{'name': 'Chasing Madoff', 'pos': [7, 9], 'sent_id': 3, 'type': 'MISC'},
#    {'type': 'MISC', 'pos': [0, 2], 'name': 'Chasing Madoff', 'sent_id': 4}],
#   [{'type': 'TIME', 'pos': [11, 12], 'name': '2010', 'sent_id': 3}],
#   [{'type': 'PER', 'pos': [19, 21], 'name': 'Bernie Madoff', 'sent_id': 3}],
#   [{'type': 'MISC', 'pos': [22, 24], 'name': 'Ponzi scheme', 'sent_id': 3}],
#   [{'name': 'International Documentary Film Festival Amsterdam',
#     'pos': [5, 10],
#     'sent_id': 4,
#     'type': 'MISC'}],
#   [{'name': 'the United States',
#     'pos': [14, 17],
#     'sent_id': 4,
#     'type': 'LOC'}],
#   [{'type': 'ORG',
#     'pos': [18, 21],
#     'name': 'Cohen Media Group',
#     'sent_id': 4}],
#   [{'name': 'Entertainment One',
#     'pos': [25, 27],
#     'sent_id': 4,
#     'type': 'ORG'}],
#   [{'type': 'MISC', 'pos': [7, 8], 'name': 'Monogamy', 'sent_id': 5}],
#   [{'name': 'Tribeca Film Festival',
#     'pos': [16, 19],
#     'sent_id': 5,
#     'type': 'MISC'}],
#   [{'name': 'Oscilloscope Laboratories',
#     'pos': [23, 25],
#     'sent_id': 5,
#     'type': 'ORG'}],
#   [{'type': 'MISC', 'pos': [15, 17], 'name': 'The Daily', 'sent_id': 6}],
#   [{'name': 'News Corporation', 'pos': [24, 26], 'sent_id': 6, 'type': 'ORG'}],
#   [{'type': 'MISC', 'pos': [28, 29], 'name': 'iPad', 'sent_id': 6}],
#   [{'name': 'IBM', 'pos': [18, 19], 'sent_id': 7, 'type': 'ORG'}],
#   [{'name': 'BBC Worldwide', 'pos': [20, 22], 'sent_id': 7, 'type': 'ORG'}],
#   [{'name': 'Dell', 'pos': [23, 24], 'sent_id': 7, 'type': 'ORG'}],
#   [{'name': 'Reuters', 'pos': [25, 26], 'sent_id': 7, 'type': 'ORG'}],
#   [{'name': 'Johnson & Johnson',
#     'pos': [27, 30],
#     'sent_id': 7,
#     'type': 'ORG'}],
#   [{'name': 'ThinkFilm', 'pos': [31, 32], 'sent_id': 7, 'type': 'ORG'}],
#   [{'name': 'Cynthia Rowley', 'pos': [33, 35], 'sent_id': 7, 'type': 'ORG'}],
#   [{'name': 'Centre for Addiction and Mental Health',
#     'pos': [36, 42],
#     'sent_id': 7,
#     'type': 'ORG'}]],
#  'labels': [{'r': 'P569', 'h': 0, 't': 1, 'evidence': [0]},
#   {'r': 'P131', 'h': 6, 't': 7, 'evidence': [2]},
#   {'r': 'P17', 'h': 6, 't': 8, 'evidence': [2]},
#   {'r': 'P17', 'h': 7, 't': 8, 'evidence': [2]},
#   {'r': 'P131', 'h': 7, 't': 8, 'evidence': [2]},
#   {'r': 'P150', 'h': 8, 't': 7, 'evidence': [2]},
#   {'r': 'P131', 'h': 2, 't': 7, 'evidence': [2]},
#   {'r': 'P57', 'h': 9, 't': 0, 'evidence': [0, 3]},
#   {'r': 'P577', 'h': 9, 't': 10, 'evidence': [3]}],
#  'title': 'Jeff Prosserman',
#  'sents': [['Jeff',
#    'Prosserman',
#    '(',
#    'born',
#    'November',
#    '2',
#    ',',
#    '1983',
#    ')',
#    'is',
#    'a',
#    'Canadian',
#    'cross',
#    '-',
#    'platform',
#    'producer',
#    'and',
#    'director',
#    'with',
#    'experience',
#    'in',
#    'film',
#    ',',
#    'interactive',
#    ',',
#    'and',
#    'mobile',
#    'content',
#    'strategy',
#    ',',
#    'development',
#    ',',
#    'and',
#    'production',
#    '.'],
#   ['Prior',
#    'to',
#    'founding',
#    'LIVESTAGE',
#    '°',
#    ',',
#    'Prosserman',
#    'was',
#    'the',
#    'Founder',
#    'of',
#    'Gusto',
#    'Goods',
#    ',',
#    'a',
#    'production',
#    'company',
#    'based',
#    'in',
#    'New',
#    'York',
#    'and',
#    'Toronto',
#    '.'],
#   ['Prosserman',
#    'was',
#    'born',
#    'in',
#    'Toronto',
#    ',',
#    'Ontario',
#    ',',
#    'Canada',
#    '.'],
#   ['He',
#    'produced',
#    ',',
#    'wrote',
#    ',',
#    'and',
#    'directed',
#    'Chasing',
#    'Madoff',
#    ',',
#    'a',
#    '2010',
#    'feature',
#    'documentary',
#    'on',
#    'an',
#    'attempt',
#    'to',
#    'expose',
#    'Bernie',
#    'Madoff',
#    "'s",
#    'Ponzi',
#    'scheme',
#    '.'],
#   ['Chasing',
#    'Madoff',
#    'premiered',
#    'at',
#    'the',
#    'International',
#    'Documentary',
#    'Film',
#    'Festival',
#    'Amsterdam',
#    'and',
#    'was',
#    'distributed',
#    'across',
#    'the',
#    'United',
#    'States',
#    'by',
#    'Cohen',
#    'Media',
#    'Group',
#    'and',
#    'in',
#    'Canada',
#    'by',
#    'Entertainment',
#    'One',
#    '.'],
#   ['Prosserman',
#    'was',
#    'also',
#    'the',
#    'Executive',
#    'Producer',
#    'of',
#    'Monogamy',
#    ',',
#    'a',
#    'feature',
#    'film',
#    'that',
#    'premiered',
#    'at',
#    'the',
#    'Tribeca',
#    'Film',
#    'Festival',
#    'and',
#    'was',
#    'released',
#    'by',
#    'Oscilloscope',
#    'Laboratories',
#    '.'],
#   ['Following',
#    'the',
#    'release',
#    'of',
#    'these',
#    'films',
#    ',',
#    'Prosserman',
#    'worked',
#    'as',
#    'a',
#    'content',
#    'producer',
#    'to',
#    'launch',
#    'The',
#    'Daily',
#    ',',
#    'the',
#    'first',
#    'digital',
#    'publication',
#    'created',
#    'by',
#    'News',
#    'Corporation',
#    'for',
#    'the',
#    'iPad',
#    '.'],
#   ['Over',
#    'the',
#    'course',
#    'of',
#    'his',
#    'career',
#    ',',
#    'Prosserman',
#    'has',
#    'produced',
#    'global',
#    'interactive',
#    'advertising',
#    'campaigns',
#    'with',
#    'clients',
#    'that',
#    'include',
#    'IBM',
#    ',',
#    'BBC',
#    'Worldwide',
#    ',',
#    'Dell',
#    ',',
#    'Reuters',
#    ',',
#    'Johnson',
#    '&',
#    'Johnson',
#    ',',
#    'ThinkFilm',
#    ',',
#    'Cynthia',
#    'Rowley',
#    ',',
#    'Centre',
#    'for',
#    'Addiction',
#    'and',
#    'Mental',
#    'Health',
#    ',',
#    'and',
#    'many',
#    'more',
#    '.'],
#   ['As',
#    'the',
#    'Co',
#    '-',
#    'Founder',
#    'and',
#    'Chief',
#    'Creative',
#    'Officer',
#    'for',
#    'LIVESTAGE',
#    '°',
#    ',',
#    'Prosserman',
#    'is',
#    'responsible',
#    'for',
#    'product',
#    'development',
#    ',',
#    'content',
#    ',',
#    'and',
#    'design',
#    ',',
#    'while',
#    'guiding',
#    'the',
#    'creative',
#    'and',
#    'brand',
#    'direction',
#    'for',
#    'the',
#    'company',
#    '.']]}

# %%
from transformers import AutoTokenizer, AutoConfig

tokenizer = AutoTokenizer.from_pretrained(
    'allenai/longformer-base-4096')

tokens = tokenizer.encode("This is a sentence from [MASK] training data")
tokens = tokenizer.convert_ids_to_tokens(tokens)
tokens
# Out:
# ['<s>',
#  'This',
#  'Ġis',
#  'Ġa',
#  'Ġsentence',
#  'Ġfrom',
#  'Ġ[',
#  'MAS',
#  'K',
#  ']',
#  'Ġtraining',
#  'Ġdata',
#  '</s>']

# %%
def find_sub_list(sl,l):
    results=[]
    sll=len(sl)
    for ind in (i for i,e in enumerate(l) if e==sl[0]):
        if l[ind:ind+sll]==sl:
            results.append((ind,ind+sll))

    return results

def tokenize(string):
    tokens = tokenizer.encode(string)
    tokens = tokenizer.convert_ids_to_tokens(tokens)
    return tokens[1:-1]

# %%
entity = data[0]['vertexSet'][0][0]

sents = data[0]['sents']

entity_name = entity['name']
sent = sents[entity['sent_id']]
sent = ' '.join(sent)

entity_tokens = tokenizer.encode(entity_name)
entity_tokens = tokenizer.convert_ids_to_tokens(entity_tokens)[1:-1]

sent_tokens = tokenizer.encode(sent)
sent_tokens = tokenizer.convert_ids_to_tokens(sent_tokens)[1:-1]

# %%
find_sub_list(entity_tokens,sent_tokens)
# Out:
# [(0, 3)]

# %%
sent_tokens
# Out:
# ['G',
#  'amb',
#  'ier',
#  'ĠIsland',
#  'Ġis',
#  'Ġan',
#  'Ġisland',
#  'Ġlocated',
#  'Ġin',
#  'ĠHowe',
#  'ĠSound',
#  'Ġnear',
#  'ĠVancouver',
#  'Ġ,',
#  'ĠBritish',
#  'ĠColumbia',
#  'Ġ.']

# %%
# Opening JSON file
f = open('../data/docred_joint/types.json')
  
# returns JSON object as 
# a dictionary
types = json.load(f)

relations_dict = types['relations']

# %%
relations_dict
# Out:
# {'P1376': {'symmetric': False, 'short': 'P1376', 'verbose': 'capital of'},
#  'P607': {'symmetric': False, 'short': 'P607', 'verbose': 'conflict'},
#  'P136': {'symmetric': False, 'short': 'P136', 'verbose': 'genre'},
#  'P137': {'symmetric': False, 'short': 'P137', 'verbose': 'operator'},
#  'P131': {'symmetric': False,
#   'short': 'P131',
#   'verbose': 'located in the administrative territorial entity'},
#  'P527': {'symmetric': False, 'short': 'P527', 'verbose': 'has part'},
#  'P1412': {'symmetric': False,
#   'short': 'P1412',
#   'verbose': 'languages spoken, written or signed'},
#  'P206': {'symmetric': False,
#   'short': 'P206',
#   'verbose': 'located in or next to body of water'},
#  'P205': {'symmetric': False, 'short': 'P205', 'verbose': 'basin country'},
#  'P449': {'symmetric': False, 'short': 'P449', 'verbose': 'original network'},
#  'P127': {'symmetric': False, 'short': 'P127', 'verbose': 'owned by'},
#  'P123': {'symmetric': False, 'short': 'P123', 'verbose': 'publisher'},
#  'P86': {'symmetric': False, 'short': 'P86', 'verbose': 'composer'},
#  'P840': {'symmetric': False,
#   'short': 'P840',
#   'verbose': 'narrative location'},
#  'P355': {'symmetric': False, 'short': 'P355', 'verbose': 'subsidiary'},
#  'P737': {'symmetric': False, 'short': 'P737', 'verbose': 'influenced by'},
#  'P740': {'symmetric': False,
#   'short': 'P740',
#   'verbose': 'location of formation'},
#  'P190': {'symmetric': False, 'short': 'P190', 'verbose': 'sister city'},
#  'P576': {'symmetric': False,
#   'short': 'P576',
#   'verbose': 'dissolved, abolished or demolished'},
#  'P194': {'symmetric': False, 'short': 'P194', 'verbose': 'legislative body'},
#  'P112': {'symmetric': False, 'short': 'P112', 'verbose': 'founded by'},
#  'P118': {'symmetric': False, 'short': 'P118', 'verbose': 'league'},
#  'P17': {'symmetric': False, 'short': 'P17', 'verbose': 'country'},
#  'P19': {'symmetric': False, 'short': 'P19', 'verbose': 'place of birth'},
#  'P3373': {'symmetric': False, 'short': 'P3373', 'verbose': 'sibling'},
#  'P6': {'symmetric': False, 'short': 'P6', 'verbose': 'head of government'},
#  'P276': {'symmetric': False, 'short': 'P276', 'verbose': 'location'},
#  'P1001': {'symmetric': False,
#   'short': 'P1001',
#   'verbose': 'applies to jurisdiction'},
#  'P580': {'symmetric': False, 'short': 'P580', 'verbose': 'start time'},
#  'P582': {'symmetric': False, 'short': 'P582', 'verbose': 'end time'},
#  'P585': {'symmetric': False, 'short': 'P585', 'verbose': 'point in time'},
#  'P463': {'symmetric': False, 'short': 'P463', 'verbose': 'member of'},
#  'P676': {'symmetric': False, 'short': 'P676', 'verbose': 'lyrics by'},
#  'P674': {'symmetric': False, 'short': 'P674', 'verbose': 'characters'},
#  'P264': {'symmetric': False, 'short': 'P264', 'verbose': 'record label'},
#  'P108': {'symmetric': False, 'short': 'P108', 'verbose': 'employer'},
#  'P102': {'symmetric': False,
#   'short': 'P102',
#   'verbose': 'member of political party'},
#  'P25': {'symmetric': False, 'short': 'P25', 'verbose': 'mother'},
#  'P27': {'symmetric': False,
#   'short': 'P27',
#   'verbose': 'country of citizenship'},
#  'P26': {'symmetric': False, 'short': 'P26', 'verbose': 'spouse'},
#  'P20': {'symmetric': False, 'short': 'P20', 'verbose': 'place of death'},
#  'P22': {'symmetric': False, 'short': 'P22', 'verbose': 'father'},
#  'P807': {'symmetric': False, 'short': 'P807', 'verbose': 'separated from'},
#  'P800': {'symmetric': False, 'short': 'P800', 'verbose': 'notable work'},
#  'P279': {'symmetric': False, 'short': 'P279', 'verbose': 'subclass of'},
#  'P1336': {'symmetric': False,
#   'short': 'P1336',
#   'verbose': 'territory claimed by'},
#  'P577': {'symmetric': False, 'short': 'P577', 'verbose': 'publication date'},
#  'P570': {'symmetric': False, 'short': 'P570', 'verbose': 'date of death'},
#  'P571': {'symmetric': False, 'short': 'P571', 'verbose': 'inception'},
#  'P178': {'symmetric': False, 'short': 'P178', 'verbose': 'developer'},
#  'P179': {'symmetric': False, 'short': 'P179', 'verbose': 'series'},
#  'P272': {'symmetric': False,
#   'short': 'P272',
#   'verbose': 'production company'},
#  'P170': {'symmetric': False, 'short': 'P170', 'verbose': 'creator'},
#  'P171': {'symmetric': False, 'short': 'P171', 'verbose': 'parent taxon'},
#  'P172': {'symmetric': False, 'short': 'P172', 'verbose': 'ethnic group'},
#  'P175': {'symmetric': False, 'short': 'P175', 'verbose': 'performer'},
#  'P176': {'symmetric': False, 'short': 'P176', 'verbose': 'manufacturer'},
#  'P39': {'symmetric': False, 'short': 'P39', 'verbose': 'position held'},
#  'P30': {'symmetric': False, 'short': 'P30', 'verbose': 'continent'},
#  'P31': {'symmetric': False, 'short': 'P31', 'verbose': 'instance of'},
#  'P36': {'symmetric': False, 'short': 'P36', 'verbose': 'capital'},
#  'P37': {'symmetric': False, 'short': 'P37', 'verbose': 'official language'},
#  'P35': {'symmetric': False, 'short': 'P35', 'verbose': 'head of state'},
#  'P400': {'symmetric': False, 'short': 'P400', 'verbose': 'platform'},
#  'P403': {'symmetric': False,
#   'short': 'P403',
#   'verbose': 'mouth of the watercourse'},
#  'P361': {'symmetric': False, 'short': 'P361', 'verbose': 'part of'},
#  'P364': {'symmetric': False,
#   'short': 'P364',
#   'verbose': 'original language of work'},
#  'P569': {'symmetric': False, 'short': 'P569', 'verbose': 'date of birth'},
#  'P710': {'symmetric': False, 'short': 'P710', 'verbose': 'participant'},
#  'P1344': {'symmetric': False, 'short': 'P1344', 'verbose': 'participant of'},
#  'P488': {'symmetric': False, 'short': 'P488', 'verbose': 'chairperson'},
#  'P241': {'symmetric': False, 'short': 'P241', 'verbose': 'military branch'},
#  'P162': {'symmetric': False, 'short': 'P162', 'verbose': 'producer'},
#  'P161': {'symmetric': False, 'short': 'P161', 'verbose': 'cast member'},
#  'P166': {'symmetric': False, 'short': 'P166', 'verbose': 'award received'},
#  'P40': {'symmetric': False, 'short': 'P40', 'verbose': 'child'},
#  'P1441': {'symmetric': False, 'short': 'P1441', 'verbose': 'present in work'},
#  'P156': {'symmetric': False, 'short': 'P156', 'verbose': 'followed by'},
#  'P155': {'symmetric': False, 'short': 'P155', 'verbose': 'follows'},
#  'P150': {'symmetric': False,
#   'short': 'P150',
#   'verbose': 'contains administrative territorial entity'},
#  'P551': {'symmetric': False, 'short': 'P551', 'verbose': 'residence'},
#  'P706': {'symmetric': False,
#   'short': 'P706',
#   'verbose': 'located on terrain feature'},
#  'P159': {'symmetric': False,
#   'short': 'P159',
#   'verbose': 'headquarters location'},
#  'P495': {'symmetric': False, 'short': 'P495', 'verbose': 'country of origin'},
#  'P58': {'symmetric': False, 'short': 'P58', 'verbose': 'screenwriter'},
#  'P749': {'symmetric': False,
#   'short': 'P749',
#   'verbose': 'parent organization'},
#  'P54': {'symmetric': False,
#   'short': 'P54',
#   'verbose': 'member of sports team'},
#  'P57': {'symmetric': False, 'short': 'P57', 'verbose': 'director'},
#  'P50': {'symmetric': False, 'short': 'P50', 'verbose': 'author'},
#  'P1366': {'symmetric': False, 'short': 'P1366', 'verbose': 'replaced by'},
#  'P1365': {'symmetric': False, 'short': 'P1365', 'verbose': 'replaces'},
#  'P937': {'symmetric': False, 'short': 'P937', 'verbose': 'work location'},
#  'P140': {'symmetric': False, 'short': 'P140', 'verbose': 'religion'},
#  'P69': {'symmetric': False, 'short': 'P69', 'verbose': 'educated at'},
#  'P1198': {'symmetric': False,
#   'short': 'P1198',
#   'verbose': 'unemployment rate'},
#  'P1056': {'symmetric': False,
#   'short': 'P1056',
#   'verbose': 'product or material produced'}}

# %%
docs = []

for doc in data:
    new_doc = {}
    new_doc['vertexSet'] = doc['vertexSet']
    new_doc['labels'] = doc['labels']
    new_doc['title'] = doc['title']
    new_doc['sents'] = doc['sents']
    
    sents = doc['sents']
    tokenized_sents = []
    
    entities_dict = {}
    for entities in doc['vertexSet']:
        for entity in entities:
            new_entity = entity
            
            entity_name = entity['name']
            sent = sents[entity['sent_id']]
            sent = ' '.join(sent)
            
            if entity['pos'][0] == 0:
                tokens = []
            else:
                tokens = ['* ']
            tokens.extend(sents[entity['sent_id']][entity['pos'][0]:entity['pos'][1]])
#             print(' un '.join(tokens))
            entity_tokens = tokenize(' * '.join(tokens))
            entity_tokens = list(filter(('*').__ne__, entity_tokens))
            entity_tokens = list(filter(('Ġ*').__ne__, entity_tokens))
            if entity['pos'][0] > 0:
                entity_tokens = entity_tokens[1:]
            sent_tokens = tokenize(sent)
#             print("entity_tokens: ",entity_tokens)
#             print("sent_tokens: ", sent_tokens)
            
            new_pos = find_sub_list(entity_tokens,sent_tokens)
            
            if len(new_pos) > 0:
                new_entity['new_pos'] = new_pos[0]
#                 print(sent_tokens[new_pos[0][0]:new_pos[0][1]])
                entities_dict[str(entity['pos'][0]) + '_' + str(entity['pos'][1]) + '_' + str(entity['sent_id'])] = new_entity
            else:
                print("NEW ENTITY: ",new_entity)
                print("entity_tokens: ",entity_tokens)
                print("sent_tokens: ", sent_tokens)
                
    for sent in doc['sents']:
        sent = ' '.join(sent)
        sent_tokens = tokenize(sent)
        tokenized_sents.append(sent_tokens)
    
    relations = []
    entities = []
    for relation in doc['labels']:
        relationship = relations_dict[relation['r']]['verbose']
        relationship = relationship.title()
        relationship = relationship.replace(" ","")
        
        sub = doc['vertexSet'][relation['h']][0]
        sub_dict_key = str(sub['pos'][0]) + '_' + str(sub['pos'][1]) + '_' + str(sub['sent_id'])
        
        obj = doc['vertexSet'][relation['t']][0]
        obj_dict_key = str(obj['pos'][0]) + '_' + str(obj['pos'][1]) + '_' + str(obj['sent_id'])
        
        sub_ent = None
        obj_ent = None
        
        if sub_dict_key in entities_dict:
            sub_ent = entities_dict[sub_dict_key]
            entities.append(sub_ent)
        if obj_dict_key in entities_dict:
            obj_ent = entities_dict[obj_dict_key]
            entities.append(obj_ent)
        
        if sub_ent and obj_ent:
            relation_dict = {}
            relation_dict['relation'] = relationship
            sub_dict_key = str(sub_ent['new_pos'][0]) + '_' + str(sub_ent['new_pos'][1]) + '_' + str(sub_ent['sent_id'])
            relation_dict['sub'] = sub_dict_key
            obj_dict_key = str(obj_ent['new_pos'][0]) + '_' + str(obj_ent['new_pos'][1]) + '_' + str(obj_ent['sent_id'])
            relation_dict['obj'] = obj_dict_key
            relations.append(relation_dict)
            
    new_doc['entities'] = entities
    new_doc['relations'] = relations
    new_doc['tokenized_sents'] = tokenized_sents
    docs.append(new_doc)

# %%
docs[0]
# Out:
# {'vertexSet': [[{'name': 'Jeff Prosserman',
#     'pos': [0, 2],
#     'sent_id': 0,
#     'type': 'PER',
#     'new_pos': (0, 4)},
#    {'type': 'PER',
#     'pos': [7, 8],
#     'name': 'Prosserman',
#     'sent_id': 7,
#     'new_pos': (7, 10)},
#    {'type': 'PER',
#     'pos': [6, 7],
#     'name': 'Prosserman',
#     'sent_id': 1,
#     'new_pos': (9, 12)},
#    {'type': 'PER',
#     'pos': [7, 8],
#     'name': 'Prosserman',
#     'sent_id': 6,
#     'new_pos': (7, 10)},
#    {'type': 'PER',
#     'pos': [13, 14],
#     'name': 'Prosserman',
#     'sent_id': 8,
#     'new_pos': (16, 19)},
#    {'type': 'PER',
#     'pos': [0, 1],
#     'name': 'Prosserman',
#     'sent_id': 2,
#     'new_pos': (0, 3)},
#    {'type': 'PER',
#     'pos': [0, 1],
#     'name': 'Prosserman',
#     'sent_id': 5,
#     'new_pos': (0, 3)}],
#   [{'type': 'TIME',
#     'pos': [4, 8],
#     'name': 'November 2, 1983',
#     'sent_id': 0,
#     'new_pos': (6, 10)}],
#   [{'name': 'Canadian',
#     'pos': [11, 12],
#     'sent_id': 0,
#     'type': 'LOC',
#     'new_pos': (13, 14)}],
#   [{'type': 'ORG',
#     'pos': [3, 5],
#     'name': 'LIVESTAGE °',
#     'sent_id': 1,
#     'new_pos': (3, 8)},
#    {'name': 'LIVESTAGE °',
#     'pos': [10, 12],
#     'sent_id': 8,
#     'type': 'ORG',
#     'new_pos': (10, 15)}],
#   [{'type': 'ORG',
#     'pos': [11, 13],
#     'name': 'Gusto Goods',
#     'sent_id': 1,
#     'new_pos': (16, 19)}],
#   [{'name': 'New York',
#     'pos': [19, 21],
#     'sent_id': 1,
#     'type': 'LOC',
#     'new_pos': (25, 27)}],
#   [{'name': 'Toronto',
#     'pos': [22, 23],
#     'sent_id': 1,
#     'type': 'LOC',
#     'new_pos': (28, 29)},
#    {'name': 'Toronto',
#     'pos': [4, 5],
#     'sent_id': 2,
#     'type': 'LOC',
#     'new_pos': (6, 7)}],
#   [{'name': 'Ontario',
#     'pos': [6, 7],
#     'sent_id': 2,
#     'type': 'LOC',
#     'new_pos': (8, 9)}],
#   [{'name': 'Canada',
#     'pos': [8, 9],
#     'sent_id': 2,
#     'type': 'LOC',
#     'new_pos': (10, 11)},
#    {'name': 'Canada',
#     'pos': [23, 24],
#     'sent_id': 4,
#     'type': 'LOC',
#     'new_pos': (26, 27)}],
#   [{'name': 'Chasing Madoff',
#     'pos': [7, 9],
#     'sent_id': 3,
#     'type': 'MISC',
#     'new_pos': (7, 11)},
#    {'type': 'MISC',
#     'pos': [0, 2],
#     'name': 'Chasing Madoff',
#     'sent_id': 4,
#     'new_pos': (0, 4)}],
#   [{'type': 'TIME',
#     'pos': [11, 12],
#     'name': '2010',
#     'sent_id': 3,
#     'new_pos': (13, 14)}],
#   [{'type': 'PER',
#     'pos': [19, 21],
#     'name': 'Bernie Madoff',
#     'sent_id': 3,
#     'new_pos': (21, 24)}],
#   [{'type': 'MISC',
#     'pos': [22, 24],
#     'name': 'Ponzi scheme',
#     'sent_id': 3,
#     'new_pos': (26, 30)}],
#   [{'name': 'International Documentary Film Festival Amsterdam',
#     'pos': [5, 10],
#     'sent_id': 4,
#     'type': 'MISC',
#     'new_pos': (7, 13)}],
#   [{'name': 'the United States',
#     'pos': [14, 17],
#     'sent_id': 4,
#     'type': 'LOC',
#     'new_pos': (17, 20)}],
#   [{'type': 'ORG',
#     'pos': [18, 21],
#     'name': 'Cohen Media Group',
#     'sent_id': 4,
#     'new_pos': (21, 24)}],
#   [{'name': 'Entertainment One',
#     'pos': [25, 27],
#     'sent_id': 4,
#     'type': 'ORG',
#     'new_pos': (28, 30)}],
#   [{'type': 'MISC',
#     'pos': [7, 8],
#     'name': 'Monogamy',
#     'sent_id': 5,
#     'new_pos': (9, 12)}],
#   [{'name': 'Tribeca Film Festival',
#     'pos': [16, 19],
#     'sent_id': 5,
#     'type': 'MISC',
#     'new_pos': (20, 24)}],
#   [{'name': 'Oscilloscope Laboratories',
#     'pos': [23, 25],
#     'sent_id': 5,
#     'type': 'ORG',
#     'new_pos': (28, 32)}],
#   [{'type': 'MISC',
#     'pos': [15, 17],
#     'name': 'The Daily',
#     'sent_id': 6,
#     'new_pos': (17, 19)}],
#   [{'name': 'News Corporation',
#     'pos': [24, 26],
#     'sent_id': 6,
#     'type': 'ORG',
#     'new_pos': (26, 28)}],
#   [{'type': 'MISC',
#     'pos': [28, 29],
#     'name': 'iPad',
#     'sent_id': 6,
#     'new_pos': (30, 31)}],
#   [{'name': 'IBM',
#     'pos': [18, 19],
#     'sent_id': 7,
#     'type': 'ORG',
#     'new_pos': (20, 21)}],
#   [{'name': 'BBC Worldwide',
#     'pos': [20, 22],
#     'sent_id': 7,
#     'type': 'ORG',
#     'new_pos': (22, 24)}],
#   [{'name': 'Dell',
#     'pos': [23, 24],
#     'sent_id': 7,
#     'type': 'ORG',
#     'new_pos': (25, 26)}],
#   [{'name': 'Reuters',
#     'pos': [25, 26],
#     'sent_id': 7,
#     'type': 'ORG',
#     'new_pos': (27, 28)}],
#   [{'name': 'Johnson & Johnson',
#     'pos': [27, 30],
#     'sent_id': 7,
#     'type': 'ORG',
#     'new_pos': (29, 32)}],
#   [{'name': 'ThinkFilm',
#     'pos': [31, 32],
#     'sent_id': 7,
#     'type': 'ORG',
#     'new_pos': (33, 35)}],
#   [{'name': 'Cynthia Rowley',
#     'pos': [33, 35],
#     'sent_id': 7,
#     'type': 'ORG',
#     'new_pos': (36, 39)}],
#   [{'name': 'Centre for Addiction and Mental Health',
#     'pos': [36, 42],
#     'sent_id': 7,
#     'type': 'ORG',
#     'new_pos': (40, 46)}]],
#  'labels': [{'r': 'P569', 'h': 0, 't': 1, 'evidence': [0]},
#   {'r': 'P131', 'h': 6, 't': 7, 'evidence': [2]},
#   {'r': 'P17', 'h': 6, 't': 8, 'evidence': [2]},
#   {'r': 'P17', 'h': 7, 't': 8, 'evidence': [2]},
#   {'r': 'P131', 'h': 7, 't': 8, 'evidence': [2]},
#   {'r': 'P150', 'h': 8, 't': 7, 'evidence': [2]},
#   {'r': 'P131', 'h': 2, 't': 7, 'evidence': [2]},
#   {'r': 'P57', 'h': 9, 't': 0, 'evidence': [0, 3]},
#   {'r': 'P577', 'h': 9, 't': 10, 'evidence': [3]}],
#  'title': 'Jeff Prosserman',
#  'sents': [['Jeff',
#    'Prosserman',
#    '(',
#    'born',
#    'November',
#    '2',
#    ',',
#    '1983',
#    ')',
#    'is',
#    'a',
#    'Canadian',
#    'cross',
#    '-',
#    'platform',
#    'producer',
#    'and',
#    'director',
#    'with',
#    'experience',
#    'in',
#    'film',
#    ',',
#    'interactive',
#    ',',
#    'and',
#    'mobile',
#    'content',
#    'strategy',
#    ',',
#    'development',
#    ',',
#    'and',
#    'production',
#    '.'],
#   ['Prior',
#    'to',
#    'founding',
#    'LIVESTAGE',
#    '°',
#    ',',
#    'Prosserman',
#    'was',
#    'the',
#    'Founder',
#    'of',
#    'Gusto',
#    'Goods',
#    ',',
#    'a',
#    'production',
#    'company',
#    'based',
#    'in',
#    'New',
#    'York',
#    'and',
#    'Toronto',
#    '.'],
#   ['Prosserman',
#    'was',
#    'born',
#    'in',
#    'Toronto',
#    ',',
#    'Ontario',
#    ',',
#    'Canada',
#    '.'],
#   ['He',
#    'produced',
#    ',',
#    'wrote',
#    ',',
#    'and',
#    'directed',
#    'Chasing',
#    'Madoff',
#    ',',
#    'a',
#    '2010',
#    'feature',
#    'documentary',
#    'on',
#    'an',
#    'attempt',
#    'to',
#    'expose',
#    'Bernie',
#    'Madoff',
#    "'s",
#    'Ponzi',
#    'scheme',
#    '.'],
#   ['Chasing',
#    'Madoff',
#    'premiered',
#    'at',
#    'the',
#    'International',
#    'Documentary',
#    'Film',
#    'Festival',
#    'Amsterdam',
#    'and',
#    'was',
#    'distributed',
#    'across',
#    'the',
#    'United',
#    'States',
#    'by',
#    'Cohen',
#    'Media',
#    'Group',
#    'and',
#    'in',
#    'Canada',
#    'by',
#    'Entertainment',
#    'One',
#    '.'],
#   ['Prosserman',
#    'was',
#    'also',
#    'the',
#    'Executive',
#    'Producer',
#    'of',
#    'Monogamy',
#    ',',
#    'a',
#    'feature',
#    'film',
#    'that',
#    'premiered',
#    'at',
#    'the',
#    'Tribeca',
#    'Film',
#    'Festival',
#    'and',
#    'was',
#    'released',
#    'by',
#    'Oscilloscope',
#    'Laboratories',
#    '.'],
#   ['Following',
#    'the',
#    'release',
#    'of',
#    'these',
#    'films',
#    ',',
#    'Prosserman',
#    'worked',
#    'as',
#    'a',
#    'content',
#    'producer',
#    'to',
#    'launch',
#    'The',
#    'Daily',
#    ',',
#    'the',
#    'first',
#    'digital',
#    'publication',
#    'created',
#    'by',
#    'News',
#    'Corporation',
#    'for',
#    'the',
#    'iPad',
#    '.'],
#   ['Over',
#    'the',
#    'course',
#    'of',
#    'his',
#    'career',
#    ',',
#    'Prosserman',
#    'has',
#    'produced',
#    'global',
#    'interactive',
#    'advertising',
#    'campaigns',
#    'with',
#    'clients',
#    'that',
#    'include',
#    'IBM',
#    ',',
#    'BBC',
#    'Worldwide',
#    ',',
#    'Dell',
#    ',',
#    'Reuters',
#    ',',
#    'Johnson',
#    '&',
#    'Johnson',
#    ',',
#    'ThinkFilm',
#    ',',
#    'Cynthia',
#    'Rowley',
#    ',',
#    'Centre',
#    'for',
#    'Addiction',
#    'and',
#    'Mental',
#    'Health',
#    ',',
#    'and',
#    'many',
#    'more',
#    '.'],
#   ['As',
#    'the',
#    'Co',
#    '-',
#    'Founder',
#    'and',
#    'Chief',
#    'Creative',
#    'Officer',
#    'for',
#    'LIVESTAGE',
#    '°',
#    ',',
#    'Prosserman',
#    'is',
#    'responsible',
#    'for',
#    'product',
#    'development',
#    ',',
#    'content',
#    ',',
#    'and',
#    'design',
#    ',',
#    'while',
#    'guiding',
#    'the',
#    'creative',
#    'and',
#    'brand',
#    'direction',
#    'for',
#    'the',
#    'company',
#    '.']],
#  'entities': [{'name': 'Jeff Prosserman',
#    'pos': [0, 2],
#    'sent_id': 0,
#    'type': 'PER',
#    'new_pos': (0, 4)},
#   {'type': 'TIME',
#    'pos': [4, 8],
#    'name': 'November 2, 1983',
#    'sent_id': 0,
#    'new_pos': (6, 10)},
#   {'name': 'Toronto',
#    'pos': [22, 23],
#    'sent_id': 1,
#    'type': 'LOC',
#    'new_pos': (28, 29)},
#   {'name': 'Ontario',
#    'pos': [6, 7],
#    'sent_id': 2,
#    'type': 'LOC',
#    'new_pos': (8, 9)},
#   {'name': 'Toronto',
#    'pos': [22, 23],
#    'sent_id': 1,
#    'type': 'LOC',
#    'new_pos': (28, 29)},
#   {'name': 'Canada',
#    'pos': [8, 9],
#    'sent_id': 2,
#    'type': 'LOC',
#    'new_pos': (10, 11)},
#   {'name': 'Ontario',
#    'pos': [6, 7],
#    'sent_id': 2,
#    'type': 'LOC',
#    'new_pos': (8, 9)},
#   {'name': 'Canada',
#    'pos': [8, 9],
#    'sent_id': 2,
#    'type': 'LOC',
#    'new_pos': (10, 11)},
#   {'name': 'Ontario',
#    'pos': [6, 7],
#    'sent_id': 2,
#    'type': 'LOC',
#    'new_pos': (8, 9)},
#   {'name': 'Canada',
#    'pos': [8, 9],
#    'sent_id': 2,
#    'type': 'LOC',
#    'new_pos': (10, 11)},
#   {'name': 'Canada',
#    'pos': [8, 9],
#    'sent_id': 2,
#    'type': 'LOC',
#    'new_pos': (10, 11)},
#   {'name': 'Ontario',
#    'pos': [6, 7],
#    'sent_id': 2,
#    'type': 'LOC',
#    'new_pos': (8, 9)},
#   {'name': 'Canadian',
#    'pos': [11, 12],
#    'sent_id': 0,
#    'type': 'LOC',
#    'new_pos': (13, 14)},
#   {'name': 'Ontario',
#    'pos': [6, 7],
#    'sent_id': 2,
#    'type': 'LOC',
#    'new_pos': (8, 9)},
#   {'name': 'Chasing Madoff',
#    'pos': [7, 9],
#    'sent_id': 3,
#    'type': 'MISC',
#    'new_pos': (7, 11)},
#   {'name': 'Jeff Prosserman',
#    'pos': [0, 2],
#    'sent_id': 0,
#    'type': 'PER',
#    'new_pos': (0, 4)},
#   {'name': 'Chasing Madoff',
#    'pos': [7, 9],
#    'sent_id': 3,
#    'type': 'MISC',
#    'new_pos': (7, 11)},
#   {'type': 'TIME',
#    'pos': [11, 12],
#    'name': '2010',
#    'sent_id': 3,
#    'new_pos': (13, 14)}],
#  'relations': [{'relation': 'DateOfBirth', 'sub': '0_4_0', 'obj': '6_10_0'},
#   {'relation': 'LocatedInTheAdministrativeTerritorialEntity',
#    'sub': '28_29_1',
#    'obj': '8_9_2'},
#   {'relation': 'Country', 'sub': '28_29_1', 'obj': '10_11_2'},
#   {'relation': 'Country', 'sub': '8_9_2', 'obj': '10_11_2'},
#   {'relation': 'LocatedInTheAdministrativeTerritorialEntity',
#    'sub': '8_9_2',
#    'obj': '10_11_2'},
#   {'relation': 'ContainsAdministrativeTerritorialEntity',
#    'sub': '10_11_2',
#    'obj': '8_9_2'},
#   {'relation': 'LocatedInTheAdministrativeTerritorialEntity',
#    'sub': '13_14_0',
#    'obj': '8_9_2'},
#   {'relation': 'Director', 'sub': '7_11_3', 'obj': '0_4_0'},
#   {'relation': 'PublicationDate', 'sub': '7_11_3', 'obj': '13_14_3'}],
#  'tokenized_sents': [['Jeff',
#    'ĠPro',
#    'ss',
#    'erman',
#    'Ġ(',
#    'Ġborn',
#    'ĠNovember',
#    'Ġ2',
#    'Ġ,',
#    'Ġ1983',
#    'Ġ)',
#    'Ġis',
#    'Ġa',
#    'ĠCanadian',
#    'Ġcross',
#    'Ġ-',
#    'Ġplatform',
#    'Ġproducer',
#    'Ġand',
#    'Ġdirector',
#    'Ġwith',
#    'Ġexperience',
#    'Ġin',
#    'Ġfilm',
#    'Ġ,',
#    'Ġinteractive',
#    'Ġ,',
#    'Ġand',
#    'Ġmobile',
#    'Ġcontent',
#    'Ġstrategy',
#    'Ġ,',
#    'Ġdevelopment',
#    'Ġ,',
#    'Ġand',
#    'Ġproduction',
#    'Ġ.'],
#   ['Prior',
#    'Ġto',
#    'Ġfounding',
#    'ĠL',
#    'IV',
#    'EST',
#    'AGE',
#    'ĠÂ°',
#    'Ġ,',
#    'ĠPro',
#    'ss',
#    'erman',
#    'Ġwas',
#    'Ġthe',
#    'ĠFounder',
#    'Ġof',
#    'ĠGust',
#    'o',
#    'ĠGoods',
#    'Ġ,',
#    'Ġa',
#    'Ġproduction',
#    'Ġcompany',
#    'Ġbased',
#    'Ġin',
#    'ĠNew',
#    'ĠYork',
#    'Ġand',
#    'ĠToronto',
#    'Ġ.'],
#   ['P',
#    'ross',
#    'erman',
#    'Ġwas',
#    'Ġborn',
#    'Ġin',
#    'ĠToronto',
#    'Ġ,',
#    'ĠOntario',
#    'Ġ,',
#    'ĠCanada',
#    'Ġ.'],
#   ['He',
#    'Ġproduced',
#    'Ġ,',
#    'Ġwrote',
#    'Ġ,',
#    'Ġand',
#    'Ġdirected',
#    'ĠCh',
#    'asing',
#    'ĠMad',
#    'off',
#    'Ġ,',
#    'Ġa',
#    'Ġ2010',
#    'Ġfeature',
#    'Ġdocumentary',
#    'Ġon',
#    'Ġan',
#    'Ġattempt',
#    'Ġto',
#    'Ġexpose',
#    'ĠBernie',
#    'ĠMad',
#    'off',
#    "Ġ'",
#    's',
#    'ĠP',
#    'onz',
#    'i',
#    'Ġscheme',
#    'Ġ.'],
#   ['Ch',
#    'asing',
#    'ĠMad',
#    'off',
#    'Ġpremiered',
#    'Ġat',
#    'Ġthe',
#    'ĠInternational',
#    'ĠDocument',
#    'ary',
#    'ĠFilm',
#    'ĠFestival',
#    'ĠAmsterdam',
#    'Ġand',
#    'Ġwas',
#    'Ġdistributed',
#    'Ġacross',
#    'Ġthe',
#    'ĠUnited',
#    'ĠStates',
#    'Ġby',
#    'ĠCohen',
#    'ĠMedia',
#    'ĠGroup',
#    'Ġand',
#    'Ġin',
#    'ĠCanada',
#    'Ġby',
#    'ĠEntertainment',
#    'ĠOne',
#    'Ġ.'],
#   ['P',
#    'ross',
#    'erman',
#    'Ġwas',
#    'Ġalso',
#    'Ġthe',
#    'ĠExecutive',
#    'ĠProducer',
#    'Ġof',
#    'ĠMon',
#    'og',
#    'amy',
#    'Ġ,',
#    'Ġa',
#    'Ġfeature',
#    'Ġfilm',
#    'Ġthat',
#    'Ġpremiered',
#    'Ġat',
#    'Ġthe',
#    'ĠTrib',
#    'eca',
#    'ĠFilm',
#    'ĠFestival',
#    'Ġand',
#    'Ġwas',
#    'Ġreleased',
#    'Ġby',
#    'ĠO',
#    'scill',
#    'oscope',
#    'ĠLaboratories',
#    'Ġ.'],
#   ['Following',
#    'Ġthe',
#    'Ġrelease',
#    'Ġof',
#    'Ġthese',
#    'Ġfilms',
#    'Ġ,',
#    'ĠPro',
#    'ss',
#    'erman',
#    'Ġworked',
#    'Ġas',
#    'Ġa',
#    'Ġcontent',
#    'Ġproducer',
#    'Ġto',
#    'Ġlaunch',
#    'ĠThe',
#    'ĠDaily',
#    'Ġ,',
#    'Ġthe',
#    'Ġfirst',
#    'Ġdigital',
#    'Ġpublication',
#    'Ġcreated',
#    'Ġby',
#    'ĠNews',
#    'ĠCorporation',
#    'Ġfor',
#    'Ġthe',
#    'ĠiPad',
#    'Ġ.'],
#   ['Over',
#    'Ġthe',
#    'Ġcourse',
#    'Ġof',
#    'Ġhis',
#    'Ġcareer',
#    'Ġ,',
#    'ĠPro',
#    'ss',
#    'erman',
#    'Ġhas',
#    'Ġproduced',
#    'Ġglobal',
#    'Ġinteractive',
#    'Ġadvertising',
#    'Ġcampaigns',
#    'Ġwith',
#    'Ġclients',
#    'Ġthat',
#    'Ġinclude',
#    'ĠIBM',
#    'Ġ,',
#    'ĠBBC',
#    'ĠWorldwide',
#    'Ġ,',
#    'ĠDell',
#    'Ġ,',
#    'ĠReuters',
#    'Ġ,',
#    'ĠJohnson',
#    'Ġ&',
#    'ĠJohnson',
#    'Ġ,',
#    'ĠThink',
#    'Film',
#    'Ġ,',
#    'ĠCynthia',
#    'ĠRow',
#    'ley',
#    'Ġ,',
#    'ĠCentre',
#    'Ġfor',
#    'ĠAddiction',
#    'Ġand',
#    'ĠMental',
#    'ĠHealth',
#    'Ġ,',
#    'Ġand',
#    'Ġmany',
#    'Ġmore',
#    'Ġ.'],
#   ['As',
#    'Ġthe',
#    'ĠCo',
#    'Ġ-',
#    'ĠFounder',
#    'Ġand',
#    'ĠChief',
#    'ĠCreative',
#    'ĠOfficer',
#    'Ġfor',
#    'ĠL',
#    'IV',
#    'EST',
#    'AGE',
#    'ĠÂ°',
#    'Ġ,',
#    'ĠPro',
#    'ss',
#    'erman',
#    'Ġis',
#    'Ġresponsible',
#    'Ġfor',
#    'Ġproduct',
#    'Ġdevelopment',
#    'Ġ,',
#    'Ġcontent',
#    'Ġ,',
#    'Ġand',
#    'Ġdesign',
#    'Ġ,',
#    'Ġwhile',
#    'Ġguiding',
#    'Ġthe',
#    'Ġcreative',
#    'Ġand',
#    'Ġbrand',
#    'Ġdirection',
#    'Ġfor',
#    'Ġthe',
#    'Ġcompany',
#    'Ġ.']]}

# %%
pure_doc = []
doc_count = 0

for doc in docs:
    doc_dict = {}
    
    tokenized_sents_len = [len(sent) for sent in doc['tokenized_sents']]
    
    doc_dict['doc_key'] = str(doc_count)
    doc_dict['document'] = '\n'.join([' '.join(sent) for sent in doc['sents']])
    tokens = []
    for sent in doc['tokenized_sents']:
        tokens.extend(sent)
    doc_dict['tokens'] = tokens
    
    entities = []
    
    for entity in doc['entities']:
        tokens_before = tokenized_sents_len[:entity['sent_id']]
        tokens_before = sum(tokens_before)
        entity_start = entity['new_pos'][0] + tokens_before
        entity_end = entity['new_pos'][1] + tokens_before
        entities.append([entity_start,entity_end,entity['type']])
        
    relations = []
    for relation in doc['relations']:
        relation_sub_spans = relation['sub'].split('_')
        relation_sub_spans = [int(span) for span in relation_sub_spans]
        
        tokens_before = tokenized_sents_len[:relation_sub_spans[-1]]
        tokens_before = sum(tokens_before)
        sub_start = relation_sub_spans[0] + tokens_before
        sub_end = relation_sub_spans[1] + tokens_before
        
        relation_obj_spans = relation['obj'].split('_')
        relation_obj_spans = [int(span) for span in relation_obj_spans]
        
        tokens_before = tokenized_sents_len[:relation_obj_spans[-1]]
        tokens_before = sum(tokens_before)
        obj_start = relation_obj_spans[0] + tokens_before
        obj_end = relation_obj_spans[1] + tokens_before
        
        relations.append([sub_start,sub_end,obj_start,obj_end,relation['relation']])
    
    doc_count += 1

    doc_dict['ner'] = entities
    doc_dict['relations'] = relations
    
    pure_doc.append(doc_dict)

# %%
pure_doc[0]
# Out:
# {'doc_key': '0',
#  'document': "Jeff Prosserman ( born November 2 , 1983 ) is a Canadian cross - platform producer and director with experience in film , interactive , and mobile content strategy , development , and production .\nPrior to founding LIVESTAGE ° , Prosserman was the Founder of Gusto Goods , a production company based in New York and Toronto .\nProsserman was born in Toronto , Ontario , Canada .\nHe produced , wrote , and directed Chasing Madoff , a 2010 feature documentary on an attempt to expose Bernie Madoff 's Ponzi scheme .\nChasing Madoff premiered at the International Documentary Film Festival Amsterdam and was distributed across the United States by Cohen Media Group and in Canada by Entertainment One .\nProsserman was also the Executive Producer of Monogamy , a feature film that premiered at the Tribeca Film Festival and was released by Oscilloscope Laboratories .\nFollowing the release of these films , Prosserman worked as a content producer to launch The Daily , the first digital publication created by News Corporation for the iPad .\nOver the course of his career , Prosserman has produced global interactive advertising campaigns with clients that include IBM , BBC Worldwide , Dell , Reuters , Johnson & Johnson , ThinkFilm , Cynthia Rowley , Centre for Addiction and Mental Health , and many more .\nAs the Co - Founder and Chief Creative Officer for LIVESTAGE ° , Prosserman is responsible for product development , content , and design , while guiding the creative and brand direction for the company .",
#  'tokens': ['Jeff',
#   'ĠPro',
#   'ss',
#   'erman',
#   'Ġ(',
#   'Ġborn',
#   'ĠNovember',
#   'Ġ2',
#   'Ġ,',
#   'Ġ1983',
#   'Ġ)',
#   'Ġis',
#   'Ġa',
#   'ĠCanadian',
#   'Ġcross',
#   'Ġ-',
#   'Ġplatform',
#   'Ġproducer',
#   'Ġand',
#   'Ġdirector',
#   'Ġwith',
#   'Ġexperience',
#   'Ġin',
#   'Ġfilm',
#   'Ġ,',
#   'Ġinteractive',
#   'Ġ,',
#   'Ġand',
#   'Ġmobile',
#   'Ġcontent',
#   'Ġstrategy',
#   'Ġ,',
#   'Ġdevelopment',
#   'Ġ,',
#   'Ġand',
#   'Ġproduction',
#   'Ġ.',
#   'Prior',
#   'Ġto',
#   'Ġfounding',
#   'ĠL',
#   'IV',
#   'EST',
#   'AGE',
#   'ĠÂ°',
#   'Ġ,',
#   'ĠPro',
#   'ss',
#   'erman',
#   'Ġwas',
#   'Ġthe',
#   'ĠFounder',
#   'Ġof',
#   'ĠGust',
#   'o',
#   'ĠGoods',
#   'Ġ,',
#   'Ġa',
#   'Ġproduction',
#   'Ġcompany',
#   'Ġbased',
#   'Ġin',
#   'ĠNew',
#   'ĠYork',
#   'Ġand',
#   'ĠToronto',
#   'Ġ.',
#   'P',
#   'ross',
#   'erman',
#   'Ġwas',
#   'Ġborn',
#   'Ġin',
#   'ĠToronto',
#   'Ġ,',
#   'ĠOntario',
#   'Ġ,',
#   'ĠCanada',
#   'Ġ.',
#   'He',
#   'Ġproduced',
#   'Ġ,',
#   'Ġwrote',
#   'Ġ,',
#   'Ġand',
#   'Ġdirected',
#   'ĠCh',
#   'asing',
#   'ĠMad',
#   'off',
#   'Ġ,',
#   'Ġa',
#   'Ġ2010',
#   'Ġfeature',
#   'Ġdocumentary',
#   'Ġon',
#   'Ġan',
#   'Ġattempt',
#   'Ġto',
#   'Ġexpose',
#   'ĠBernie',
#   'ĠMad',
#   'off',
#   "Ġ'",
#   's',
#   'ĠP',
#   'onz',
#   'i',
#   'Ġscheme',
#   'Ġ.',
#   'Ch',
#   'asing',
#   'ĠMad',
#   'off',
#   'Ġpremiered',
#   'Ġat',
#   'Ġthe',
#   'ĠInternational',
#   'ĠDocument',
#   'ary',
#   'ĠFilm',
#   'ĠFestival',
#   'ĠAmsterdam',
#   'Ġand',
#   'Ġwas',
#   'Ġdistributed',
#   'Ġacross',
#   'Ġthe',
#   'ĠUnited',
#   'ĠStates',
#   'Ġby',
#   'ĠCohen',
#   'ĠMedia',
#   'ĠGroup',
#   'Ġand',
#   'Ġin',
#   'ĠCanada',
#   'Ġby',
#   'ĠEntertainment',
#   'ĠOne',
#   'Ġ.',
#   'P',
#   'ross',
#   'erman',
#   'Ġwas',
#   'Ġalso',
#   'Ġthe',
#   'ĠExecutive',
#   'ĠProducer',
#   'Ġof',
#   'ĠMon',
#   'og',
#   'amy',
#   'Ġ,',
#   'Ġa',
#   'Ġfeature',
#   'Ġfilm',
#   'Ġthat',
#   'Ġpremiered',
#   'Ġat',
#   'Ġthe',
#   'ĠTrib',
#   'eca',
#   'ĠFilm',
#   'ĠFestival',
#   'Ġand',
#   'Ġwas',
#   'Ġreleased',
#   'Ġby',
#   'ĠO',
#   'scill',
#   'oscope',
#   'ĠLaboratories',
#   'Ġ.',
#   'Following',
#   'Ġthe',
#   'Ġrelease',
#   'Ġof',
#   'Ġthese',
#   'Ġfilms',
#   'Ġ,',
#   'ĠPro',
#   'ss',
#   'erman',
#   'Ġworked',
#   'Ġas',
#   'Ġa',
#   'Ġcontent',
#   'Ġproducer',
#   'Ġto',
#   'Ġlaunch',
#   'ĠThe',
#   'ĠDaily',
#   'Ġ,',
#   'Ġthe',
#   'Ġfirst',
#   'Ġdigital',
#   'Ġpublication',
#   'Ġcreated',
#   'Ġby',
#   'ĠNews',
#   'ĠCorporation',
#   'Ġfor',
#   'Ġthe',
#   'ĠiPad',
#   'Ġ.',
#   'Over',
#   'Ġthe',
#   'Ġcourse',
#   'Ġof',
#   'Ġhis',
#   'Ġcareer',
#   'Ġ,',
#   'ĠPro',
#   'ss',
#   'erman',
#   'Ġhas',
#   'Ġproduced',
#   'Ġglobal',
#   'Ġinteractive',
#   'Ġadvertising',
#   'Ġcampaigns',
#   'Ġwith',
#   'Ġclients',
#   'Ġthat',
#   'Ġinclude',
#   'ĠIBM',
#   'Ġ,',
#   'ĠBBC',
#   'ĠWorldwide',
#   'Ġ,',
#   'ĠDell',
#   'Ġ,',
#   'ĠReuters',
#   'Ġ,',
#   'ĠJohnson',
#   'Ġ&',
#   'ĠJohnson',
#   'Ġ,',
#   'ĠThink',
#   'Film',
#   'Ġ,',
#   'ĠCynthia',
#   'ĠRow',
#   'ley',
#   'Ġ,',
#   'ĠCentre',
#   'Ġfor',
#   'ĠAddiction',
#   'Ġand',
#   'ĠMental',
#   'ĠHealth',
#   'Ġ,',
#   'Ġand',
#   'Ġmany',
#   'Ġmore',
#   'Ġ.',
#   'As',
#   'Ġthe',
#   'ĠCo',
#   'Ġ-',
#   'ĠFounder',
#   'Ġand',
#   'ĠChief',
#   'ĠCreative',
#   'ĠOfficer',
#   'Ġfor',
#   'ĠL',
#   'IV',
#   'EST',
#   'AGE',
#   'ĠÂ°',
#   'Ġ,',
#   'ĠPro',
#   'ss',
#   'erman',
#   'Ġis',
#   'Ġresponsible',
#   'Ġfor',
#   'Ġproduct',
#   'Ġdevelopment',
#   'Ġ,',
#   'Ġcontent',
#   'Ġ,',
#   'Ġand',
#   'Ġdesign',
#   'Ġ,',
#   'Ġwhile',
#   'Ġguiding',
#   'Ġthe',
#   'Ġcreative',
#   'Ġand',
#   'Ġbrand',
#   'Ġdirection',
#   'Ġfor',
#   'Ġthe',
#   'Ġcompany',
#   'Ġ.'],
#  'ner': [[0, 4, 'PER'],
#   [6, 10, 'TIME'],
#   [65, 66, 'LOC'],
#   [75, 76, 'LOC'],
#   [65, 66, 'LOC'],
#   [77, 78, 'LOC'],
#   [75, 76, 'LOC'],
#   [77, 78, 'LOC'],
#   [75, 76, 'LOC'],
#   [77, 78, 'LOC'],
#   [77, 78, 'LOC'],
#   [75, 76, 'LOC'],
#   [13, 14, 'LOC'],
#   [75, 76, 'LOC'],
#   [86, 90, 'MISC'],
#   [0, 4, 'PER'],
#   [86, 90, 'MISC'],
#   [92, 93, 'TIME']],
#  'relations': [[0, 4, 6, 10, 'DateOfBirth'],
#   [65, 66, 75, 76, 'LocatedInTheAdministrativeTerritorialEntity'],
#   [65, 66, 77, 78, 'Country'],
#   [75, 76, 77, 78, 'Country'],
#   [75, 76, 77, 78, 'LocatedInTheAdministrativeTerritorialEntity'],
#   [77, 78, 75, 76, 'ContainsAdministrativeTerritorialEntity'],
#   [13, 14, 75, 76, 'LocatedInTheAdministrativeTerritorialEntity'],
#   [86, 90, 0, 4, 'Director'],
#   [86, 90, 92, 93, 'PublicationDate']]}

# %%
with open("../data/docred_pure/test.jsonl", 'w') as f:
    for item in pure_doc:
        f.write(json.dumps(item, ensure_ascii=False) + "\n")
